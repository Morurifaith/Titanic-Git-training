# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore', category=FutureWarning)

# %%
sns.__version__
# Out:
# '0.13.1'

# %%
df_train=pd.read_csv(r"C:\Users\user\Downloads\train.csv")
df_test=pd.read_csv(r"C:\Users\user\Downloads\test.csv")

# %% [markdown]
# Exploratory Analysis

# %%
print(df_test.head())
print(df_train.head())
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df_train['Cabin'].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
#        'E58', 'C126', 'B71', 'B51 B53 B55', 'D49', 'B5', 'B20', 'F G63',
#        'C62 C64', 'E24', 'C90', 'C45', 'E8', 'B101', 'D45', 'C46', 'D30',
#        'E121', 'D11', 'E77', 'F38', 'B3', 'D6', 'B82 B84', 'D17', 'A36',
#        'B102', 'B69', 'E49', 'C47', 'D28', 'E17', 'A24', 'C50', 'B42',
#        'C148'], dtype=object)

# %%
df_train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
null_percentage=df_train.isnull().mean()*100
print(null_percentage)
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64

# %%
df_train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df_train.hist(figsize=(10,8))
plt.show()

# %%
# %%capture
categorical_columns=df_train.select_dtypes(include=['object','category']).columns.tolist()
# Setting up the plot size
plt.figure(figsize=(12, 8))

for column in categorical_columns:
    plt.figure()
    sns.countplot(data=df_train, x=column)
    plt.title(f'Countplot of {column}')
    plt.xticks(rotation=45)  # Rotate x-axis labels for better readability

plt.show()

# %%
sns.countplot(x='Sex', data=df_train)
plt.show()

# %%
df_train.groupby(['Survived','Sex'])['Survived'].count()
# Out:
# Survived  Sex
# 0         female     81
#           male      468
# 1         female    233
#           male      109
# Name: Survived, dtype: int64

# %%
sns.catplot(x='Sex', col='Survived', kind='count', hue='Pclass', data=df_train)

# %%
sns.catplot(x='Sex', col='Survived', kind='violin', hue='Pclass', data=df_train)

# %%
from sklearn.datasets import fetch_openml

co2 = fetch_openml(data_id=41187, as_frame=True, parser="pandas")
co2.frame.head()
# Out:
#    year  month  day  weight  flag station    co2
# 0  1958      3   29       4     0     MLO  316.1
# 1  1958      4    5       6     0     MLO  317.3
# 2  1958      4   12       4     0     MLO  317.6
# 3  1958      4   19       6     0     MLO  317.5
# 4  1958      4   26       2     0     MLO  316.4

# %%
print("% of women survived:", (df_train[df_train.Sex=='female'].Survived.sum()/df_train[df_train.Sex=='female'].Survived.count())*100)
print("% of men survived:", (df_train[df_train.Sex=='male'].Survived.sum()/df_train[df_train.Sex=='male'].Survived.count())*100)
# Out:
# % of women survived: 74.20382165605095
# % of men survived: 18.890814558058924

# %%
f, ax= plt.subplots(1,2,figsize=(16,7))
df_train['Survived'][df_train['Sex']=='male'].value_counts().plot.pie(explode=[0,0.2], autopct='%1.1f%%', ax=ax[0],shadow=True)
df_train['Survived'][df_train['Sex']=='female'].value_counts().plot.pie(explode=[0,0.2], autopct='%1.1f%%', ax=ax[1],shadow=True)
ax[0].set_title('Survived(male)')
ax[1].set_title('Survived(female)')
# Out:
# Text(0.5, 1.0, 'Survived(female)')

# %%
 pd.crosstab(df_train.Pclass, df_train.Survived, margins = True).style.background_gradient(cmap='autumn_r')
# Out:
# <style type="text/css">
# #T_9e536_row0_col0, #T_9e536_row1_col1, #T_9e536_row1_col2 {
#   background-color: #ffff00;
#   color: #000000;
# }
# #T_9e536_row0_col1 {
#   background-color: #ffce00;
#   color: #000000;
# }
# #T_9e536_row0_col2 {
#   background-color: #fff400;
#   color: #000000;
# }
# #T_9e536_row1_col0 {
#   background-color: #fff600;
#   color: #000000;
# }
# #T_9e536_row2_col0 {
#   background-color: #ff6000;
#   color: #f1f1f1;
# }
# #T_9e536_row2_col1 {
#   background-color: #ffdf00;
#   color: #000000;
# }
# #T_9e536_row2_col2 {
#   background-color: #ff9000;
#   color: #000000;
# }
# #T_9e536_row3_col0, #T_9e536_row3_col1, #T_9e536_row3_col2 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9e536">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th id="T_9e536_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_9e536_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_9e536_level0_col2" class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Pclass</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9e536_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_9e536_row0_col0" class="data row0 col0" >80</td>
#       <td id="T_9e536_row0_col1" class="data row0 col1" >136</td>
#       <td id="T_9e536_row0_col2" class="data row0 col2" >216</td>
#     </tr>
#     <tr>
#       <th id="T_9e536_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_9e536_row1_col0" class="data row1 col0" >97</td>
#       <td id="T_9e536_row1_col1" class="data row1 col1" >87</td>
#       <td id="T_9e536_row1_col2" class="data row1 col2" >184</td>
#     </tr>
#     <tr>
#       <th id="T_9e536_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_9e536_row2_col0" class="data row2 col0" >372</td>
#       <td id="T_9e536_row2_col1" class="data row2 col1" >119</td>
#       <td id="T_9e536_row2_col2" class="data row2 col2" >491</td>
#     </tr>
#     <tr>
#       <th id="T_9e536_level0_row3" class="row_heading level0 row3" >All</th>
#       <td id="T_9e536_row3_col0" class="data row3 col0" >549</td>
#       <td id="T_9e536_row3_col1" class="data row3 col1" >342</td>
#       <td id="T_9e536_row3_col2" class="data row3 col2" >891</td>
#     </tr>
#   </tbody>
# </table>

# %%
print("% of survivals in") 
print("Pclass=1 : ", df_train.Survived[df_train.Pclass == 1].sum()/df_train[df_train.Pclass == 1].Survived.count())
print("Pclass=2 : ", df_train.Survived[df_train.Pclass == 2].sum()/df_train[df_train.Pclass == 2].Survived.count())
print("Pclass=3 : ", df_train.Survived[df_train.Pclass == 3].sum()/df_train[df_train.Pclass == 3].Survived.count())
# Out:
# % of survivals in
# Pclass=1 :  0.6296296296296297
# Pclass=2 :  0.47282608695652173
# Pclass=3 :  0.24236252545824846

# %%
sns.catplot(x='Pclass',y='Survived', kind='point', data=df_train);

# %%
pd.crosstab([df_train.Sex, df_train.Survived], df_train.Pclass, margins=True).style.background_gradient(cmap='autumn_r')
# Out:
# <style type="text/css">
# #T_e26b0_row0_col0, #T_e26b0_row0_col1, #T_e26b0_row0_col3, #T_e26b0_row3_col2 {
#   background-color: #ffff00;
#   color: #000000;
# }
# #T_e26b0_row0_col2, #T_e26b0_row1_col2 {
#   background-color: #fff100;
#   color: #000000;
# }
# #T_e26b0_row1_col0 {
#   background-color: #ff9600;
#   color: #000000;
# }
# #T_e26b0_row1_col1 {
#   background-color: #ffa300;
#   color: #000000;
# }
# #T_e26b0_row1_col3 {
#   background-color: #ffcf00;
#   color: #000000;
# }
# #T_e26b0_row2_col0 {
#   background-color: #ffa700;
#   color: #000000;
# }
# #T_e26b0_row2_col1, #T_e26b0_row2_col3 {
#   background-color: #ff8500;
#   color: #f1f1f1;
# }
# #T_e26b0_row2_col2 {
#   background-color: #ff6e00;
#   color: #f1f1f1;
# }
# #T_e26b0_row3_col0 {
#   background-color: #ffcd00;
#   color: #000000;
# }
# #T_e26b0_row3_col1 {
#   background-color: #fff000;
#   color: #000000;
# }
# #T_e26b0_row3_col3 {
#   background-color: #fff700;
#   color: #000000;
# }
# #T_e26b0_row4_col0, #T_e26b0_row4_col1, #T_e26b0_row4_col2, #T_e26b0_row4_col3 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e26b0">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Pclass</th>
#       <th id="T_e26b0_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_e26b0_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_e26b0_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_e26b0_level0_col3" class="col_heading level0 col3" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="index_name level1" >Survived</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e26b0_level0_row0" class="row_heading level0 row0" rowspan="2">female</th>
#       <th id="T_e26b0_level1_row0" class="row_heading level1 row0" >0</th>
#       <td id="T_e26b0_row0_col0" class="data row0 col0" >3</td>
#       <td id="T_e26b0_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_e26b0_row0_col2" class="data row0 col2" >72</td>
#       <td id="T_e26b0_row0_col3" class="data row0 col3" >81</td>
#     </tr>
#     <tr>
#       <th id="T_e26b0_level1_row1" class="row_heading level1 row1" >1</th>
#       <td id="T_e26b0_row1_col0" class="data row1 col0" >91</td>
#       <td id="T_e26b0_row1_col1" class="data row1 col1" >70</td>
#       <td id="T_e26b0_row1_col2" class="data row1 col2" >72</td>
#       <td id="T_e26b0_row1_col3" class="data row1 col3" >233</td>
#     </tr>
#     <tr>
#       <th id="T_e26b0_level0_row2" class="row_heading level0 row2" rowspan="2">male</th>
#       <th id="T_e26b0_level1_row2" class="row_heading level1 row2" >0</th>
#       <td id="T_e26b0_row2_col0" class="data row2 col0" >77</td>
#       <td id="T_e26b0_row2_col1" class="data row2 col1" >91</td>
#       <td id="T_e26b0_row2_col2" class="data row2 col2" >300</td>
#       <td id="T_e26b0_row2_col3" class="data row2 col3" >468</td>
#     </tr>
#     <tr>
#       <th id="T_e26b0_level1_row3" class="row_heading level1 row3" >1</th>
#       <td id="T_e26b0_row3_col0" class="data row3 col0" >45</td>
#       <td id="T_e26b0_row3_col1" class="data row3 col1" >17</td>
#       <td id="T_e26b0_row3_col2" class="data row3 col2" >47</td>
#       <td id="T_e26b0_row3_col3" class="data row3 col3" >109</td>
#     </tr>
#     <tr>
#       <th id="T_e26b0_level0_row4" class="row_heading level0 row4" >All</th>
#       <th id="T_e26b0_level1_row4" class="row_heading level1 row4" ></th>
#       <td id="T_e26b0_row4_col0" class="data row4 col0" >216</td>
#       <td id="T_e26b0_row4_col1" class="data row4 col1" >184</td>
#       <td id="T_e26b0_row4_col2" class="data row4 col2" >491</td>
#       <td id="T_e26b0_row4_col3" class="data row4 col3" >891</td>
#     </tr>
#   </tbody>
# </table>

# %%
sns.catplot(x='Pclass',y='Survived',hue='Sex', kind='point', data=df_train)

# %%
sns.catplot(x='Survived', col='Embarked', kind='count', data=df_train);

# %%
sns.catplot(x='Embarked',y='Survived', kind='point', data=df_train);
